# %%
import sys
import os

package_path = ".."
if package_path not in sys.path:
    sys.path.append(package_path)

# %% [raw]
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import numpy.typing as npt
import matplotlib.pyplot as plt
import h5py
import hdf5plugin


from QoraFlow.config import ConfigManager, ExpConfig

# %%
def get_hdf5_images(file: str, config: ExpConfig) -> npt.NDArray:
    """get images form hdf5"""
    with h5py.File(file, "r") as hf:
        if "detector" not in hf:
            raise KeyError(f"Key 'detector' not found in {file}")

        images = np.asarray(
            hf[
                f"detector/{config.param.hutch.value}/{config.param.detector.value}/image/block0_values"
            ]
        )

        return images  # np.maximum(images, 0)

# %%
from QoraFlow.filesystem import get_run_scan_directory

config = load_config(reload=True)
file = get_run_scan_directory(config.path.load_dir, 18, 1, 53)
print(file)
arr = get_hdf5_images(file, config)
# Out:
# /xfel/ffs/dat/ue_250324_FXS/raw_data/h5/type=raw/run=018/scan=001/p0053.h5

# %%
np.shape(arr)
# Out:
# (600, 514, 1030)

# %%
indbad = np.where(arr < 0)

# %%
indlist = []
listmin = []

for ii in range(np.shape(arr)[0]):
    indlist.append(np.where(arr[ii, :, :] < -17500))

    listmin.append(arr[ii, :, :].min())

# %%
one_zeros = np.where(arr < -10000, 1, 0)
mask = np.nansum(one_zeros, 0)
mask[mask == 0] = 1
mask[mask == np.float32(np.shape(arr)[0])] = 0

# %%
masked_arr = arr * mask
masked_arr_sum = np.nansum(masked_arr, 0)

# %%
np.where(masked_arr_sum < 500)
# Out:
# (array([  0,   0,   0, ..., 513, 513, 513], shape=(529250,)),
#  array([   0,    1,    2, ..., 1027, 1028, 1029], shape=(529250,)))

# %%
fig1 = plt.figure(figsize=(10, 10))
ax = fig1.add_subplot(131)
arr[arr < 0] = 0
to_plot = np.nansum(arr, 0)
to_plot[11, 25] = 0
to_plot = np.transpose(to_plot)
img1 = ax.imshow(to_plot, interpolation="none")
plt.colorbar(img1)

ax2 = fig1.add_subplot(132)
masked_arr_sum[masked_arr_sum < 0] = 0
img2 = ax2.imshow(np.transpose(masked_arr_sum), interpolation="none")
plt.colorbar(img2)


ax3 = fig1.add_subplot(133)
img3 = ax3.imshow(to_plot - np.transpose(masked_arr_sum), interpolation="none")
plt.colorbar(img3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def h5_tree(val, pre="", out=""):
    length = len(val)
    for key, val in val.items():
        length -= 1
        if length == 0:  # the last item
            if type(val) == h5py._hl.group.Group:
                out += pre + "└── " + key + "\n"
                out = h5_tree(val, pre + "    ", out)
            else:
                out += pre + "└── " + key + f" {val.shape}\n"
        else:
            if type(val) == h5py._hl.group.Group:
                out += pre + "├── " + key + "\n"
                out = h5_tree(val, pre + "│   ", out)
            else:
                out += pre + "├── " + key + f" {val.shape}\n"
    return out


testh5 = config.path.load_dir + "run=018/scan=001/p0053.h5"
filename = testh5
with h5py.File(filename, "r") as file:
    structure = h5_tree(file)
    print(structure)
# Out:
# ├── detector
# │   └── eh1
# │       └── jungfrau2
# │           └── image
# │               ├── axis1 (600,)
# │               ├── block0_items (600,)
# │               └── block0_values (600, 514, 1030)
# ├── metadata
# │   ├── axis0 (196,)
# │   ├── axis1 (600,)
# │   ├── block0_items (30,)
# │   ├── block0_values (600, 30)
# │   ├── block1_items (70,)
# │   ├── block1_values (600, 70)
# │   ├── block2_items (43,)
# │   ├── block2_values (600, 43)
# │   ├── block3_items (53,)
# │   └── block3_values (1,)
# └── qbpm
#     ├── eh1
#     │   └── qbpm1
#     │       ├── waveforms.ch1
#     │       │   ├── axis0 (50000,)
#     │       │   ├── axis1 (600,)
#     │       │   ├── block0_items (50000,)
#     │       │   └── block0_values (600, 50000)
#     │       ├── waveforms.ch2
#     │       │   ├── axis0 (50000,)
#     │       │   ├── axis1 (600,)
#     │       │   ├── block0_items (50000,)
#     │       │   └── block0_values (600, 50000)
#     │       ├── waveforms.ch3
#     │       │   ├── axis0 (50000,)
#     │       │   ├── axis1 (600,)
#     │       │   ├── block0_items (50000,)
#     │       │   └── block0_values (600, 50000)
#     │       └── waveforms.ch4
#     │           ├── axis0 (50000,)
#     │           ├── axis1 (600,)
#     │           ├── block0_items (50000,)
#     │           └── block0_values (600, 50000)
#     └── oh
#         └── qbpm2
#             ├── waveforms.ch1
#             │   ├── axis0 (50000,)
#             │   ├── axis1 (600,)
#             │   ├── block0_items (50000,)
#             │   └── block0_values (600, 50000)
#             ├── waveforms.ch2
#             │   ├── axis0 (50000,)
#             │   ├── axis1 (600,)
#             │   ├── block0_items (50000,)
#             │   └── block0_values (600, 50000)
#             ├── waveforms.ch3
#             │   ├── axis0 (50000,)
#             │   ├── axis1 (600,)
#             │   ├── block0_items (50000,)
#             │   └── block0_values (600, 50000)
#             └── waveforms.ch4
#                 ├── axis0 (50000,)
#                 ├── axis1 (600,)
#                 ├── block0_items (50000,)
#                 └── block0_values (600, 50000)

# %%
filename = testh5

with h5py.File(filename, "r") as f:
    detimage = f["/detector/eh1/jungfrau2/image/block0_values"][:, :, :]

# %%
import tifffile

fn_save = (
    "/home/hxpp-admin/Desktop/sogang/250324_sogang/analysis/test_DS1/img1200_18_53.tif"
)
tifffile.imwrite(fn_save, detimage)

# %%
np.shape(detimage)

fig1 = plt.figure(figsize=(10, 10))
ax = fig1.add_subplot(111)
detimage[detimage < 0] = 0
to_plot = np.nansum(detimage[:, :, :], 0)
to_plot[to_plot > 1600] = 0
to_plot[11, 25] = 0
to_plot = to_plot
img1 = ax.imshow(to_plot, interpolation="none")
plt.colorbar(img1)
# Out:
# /tmp/ipykernel_14235/2637840111.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig1 = plt.figure(figsize=(10,10))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
filename = testh5

with h5py.File(filename, "r") as f:
    block0_items = list(f["/metadata/block0_items"])
    block1_items = list(f["/metadata/block1_items"])
    block2_items = list(f["/metadata/block2_items"])
    block3_items = list(f["/metadata/block3_items"])
    block0_values = list(f["/metadata/block0_values"])

with h5py.File(filename, "r") as f:
    # Print all root level object names (aka keys)
    # these can be group or dataset names
    print("Keys: %s" % f["/metadata/"].keys())
    # get first object name/key; may or may NOT be a group
    a_group_key = list(f.keys())[0]

    # get the object type for a_group_key: usually group or dataset
    print(type(f[a_group_key]))

    # If a_group_key is a group name,
    # this gets the object names in the group and returns as a list
    data = list(f[a_group_key])

    # If a_group_key is a dataset name,
    # this gets the dataset values and returns as a list
    data = list(f[a_group_key])
    # # preferred methods to get dataset values:
    # ds_obj = f[a_group_key]      # returns as a h5py dataset object
    # ds_arr = f[a_group_key][()]  # returns as a numpy array
# Out:
# Keys: <KeysViewHDF5 ['axis0', 'axis1', 'block0_items', 'block0_values', 'block1_items', 'block1_values', 'block2_items', 'block2_values', 'block3_items', 'block3_values']>
# <class 'h5py._hl.group.Group'>

# %%
def print_list(ll):
    for ii in range(len(ll)):
        print(f"{ii: } {ll[ii]}")


print("block 0")
print_list(block0_items)
print("block 1")
print_list(block1_items)
print("block 2")
print_list(block2_items)
print("block 3")
print_list(block3_items)
# Out:
# block 0
#  0 b'detector_eh1_jungfrau2_calibrated'
#  1 b'detector_eh1_jungfrau2_dark_bkg_substrated'
#  2 b'timestamp_info.BL_DETECTOR'
#  3 b'timestamp_info.BL_DETECTORX2'
#  4 b'timestamp_info.FIFTEEN_HERTZ'
#  5 b'timestamp_info.FIVE_HERTZ'
#  6 b'timestamp_info.RATE_HX_10HZ'
#  7 b'timestamp_info.RATE_HX_15HZ'
#  8 b'timestamp_info.RATE_HX_1HZ'
#  9 b'timestamp_info.RATE_HX_20HZ'
#  10 b'timestamp_info.RATE_HX_2HZ'
#  11 b'timestamp_info.RATE_HX_30HZ'
#  12 b'timestamp_info.RATE_HX_5HZ'
#  13 b'timestamp_info.RATE_HX_60HZ'
#  14 b'timestamp_info.RATE_HX_HALFHZ'
#  15 b'timestamp_info.RATE_SX_10HZ'
#  16 b'timestamp_info.RATE_SX_15HZ'
#  17 b'timestamp_info.RATE_SX_1HZ'
#  18 b'timestamp_info.RATE_SX_20HZ'
#  19 b'timestamp_info.RATE_SX_2HZ'
#  20 b'timestamp_info.RATE_SX_30HZ'
#  21 b'timestamp_info.RATE_SX_5HZ'
#  22 b'timestamp_info.RATE_SX_HALFHZ'
#  23 b'timestamp_info.SIXTY_HERTZ'
#  24 b'timestamp_info.TEN_HERTZ'
#  25 b'timestamp_info.THIRTY_HERTZ'
#  26 b'timestamp_info.TWENTY_HERTZ'
#  27 b'timestamp_info.XFEL_BEAM'
#  28 b'timestamp_info.XFEL_HX_BEAM'
#  29 b'timestamp_info.XFEL_SX_BEAM'
# block 1
#  0 b'th_input'
#  1 b'th_value'
#  2 b'delay_stage_eh1_delay_stage_delay_time'
#  3 b'delay_stage_eh1_delay_stage_evr_delay_tick'
#  4 b'delay_stage_eh1_delay_stage_stage_position'
#  5 b'delay_stage_eh1_delay_stage_zero_delay'
#  6 b'detector_eh1_jungfrau2_bkg_offset'
#  7 b'detector_eh1_jungfrau2_exposure_time'
#  8 b'detector_eh1_jungfrau2_statistics.max'
#  9 b'detector_eh1_jungfrau2_statistics.mean'
#  10 b'detector_eh1_jungfrau2_statistics.min'
#  11 b'detector_eh1_jungfrau2_statistics.std'
#  12 b'optics_hx_Attns_EH1_Al'
#  13 b'optics_hx_Attns_Eh1_Si'
#  14 b'optics_hx_Attns_Eh1_Transmission'
#  15 b'optics_hx_Attns_UH_Al'
#  16 b'optics_hx_Attns_UH_Si'
#  17 b'optics_hx_Attns_UH_Transmission'
#  18 b'optics_oh_DCM_crystal2_pitch'
#  19 b'optics_oh_DCM_crystal_gap'
#  20 b'optics_oh_DCM_energy'
#  21 b'qbpm_eh1_qbpm1_dev_timestamp'
#  22 b'qbpm_eh1_qbpm1_dt'
#  23 b'qbpm_eh1_qbpm1_metrics.encoding'
#  24 b'qbpm_eh1_qbpm1_metrics.parsing'
#  25 b'qbpm_eh1_qbpm1_metrics.ts_searching'
#  26 b'qbpm_eh1_qbpm1_setting.SampleRate'
#  27 b'qbpm_eh1_qbpm1_setting.triggerDelay'
#  28 b'qbpm_eh1_qbpm1_signal.ch0.base_err'
#  29 b'qbpm_eh1_qbpm1_signal.ch0.base_mean'
#  30 b'qbpm_eh1_qbpm1_signal.ch0.value'
#  31 b'qbpm_eh1_qbpm1_signal.ch0.value_err'
#  32 b'qbpm_eh1_qbpm1_signal.ch1.base_err'
#  33 b'qbpm_eh1_qbpm1_signal.ch1.base_mean'
#  34 b'qbpm_eh1_qbpm1_signal.ch1.value'
#  35 b'qbpm_eh1_qbpm1_signal.ch1.value_err'
#  36 b'qbpm_eh1_qbpm1_signal.ch2.base_err'
#  37 b'qbpm_eh1_qbpm1_signal.ch2.base_mean'
#  38 b'qbpm_eh1_qbpm1_signal.ch2.value'
#  39 b'qbpm_eh1_qbpm1_signal.ch2.value_err'
#  40 b'qbpm_eh1_qbpm1_signal.ch3.base_err'
#  41 b'qbpm_eh1_qbpm1_signal.ch3.base_mean'
#  42 b'qbpm_eh1_qbpm1_signal.ch3.value'
#  43 b'qbpm_eh1_qbpm1_signal.ch3.value_err'
#  44 b'qbpm_eh1_qbpm1_timeinterval'
#  45 b'qbpm_oh_qbpm2_dev_timestamp'
#  46 b'qbpm_oh_qbpm2_dt'
#  47 b'qbpm_oh_qbpm2_metrics.encoding'
#  48 b'qbpm_oh_qbpm2_metrics.parsing'
#  49 b'qbpm_oh_qbpm2_metrics.ts_searching'
#  50 b'qbpm_oh_qbpm2_setting.SampleRate'
#  51 b'qbpm_oh_qbpm2_setting.triggerDelay'
#  52 b'qbpm_oh_qbpm2_signal.ch0.base_err'
#  53 b'qbpm_oh_qbpm2_signal.ch0.base_mean'
#  54 b'qbpm_oh_qbpm2_signal.ch0.value'
#  55 b'qbpm_oh_qbpm2_signal.ch0.value_err'
#  56 b'qbpm_oh_qbpm2_signal.ch1.base_err'
#  57 b'qbpm_oh_qbpm2_signal.ch1.base_mean'
#  58 b'qbpm_oh_qbpm2_signal.ch1.value'
#  59 b'qbpm_oh_qbpm2_signal.ch1.value_err'
#  60 b'qbpm_oh_qbpm2_signal.ch2.base_err'
#  61 b'qbpm_oh_qbpm2_signal.ch2.base_mean'
#  62 b'qbpm_oh_qbpm2_signal.ch2.value'
#  63 b'qbpm_oh_qbpm2_signal.ch2.value_err'
#  64 b'qbpm_oh_qbpm2_signal.ch3.base_err'
#  65 b'qbpm_oh_qbpm2_signal.ch3.base_mean'
#  66 b'qbpm_oh_qbpm2_signal.ch3.value'
#  67 b'qbpm_oh_qbpm2_signal.ch3.value_err'
#  68 b'qbpm_oh_qbpm2_timeinterval'
#  69 b'timestamp_info.timestamp_offset'
# block 2
#  0 b'delay_stage_eh1_delay_stage_delay_stage.MOVN'
#  1 b'detector_eh1_jungfrau2_boardID'
#  2 b'detector_eh1_jungfrau2_bunchid'
#  3 b'detector_eh1_jungfrau2_dim1'
#  4 b'detector_eh1_jungfrau2_dim2'
#  5 b'detector_eh1_jungfrau2_epoch_ns'
#  6 b'detector_eh1_jungfrau2_evr_ts_1'
#  7 b'detector_eh1_jungfrau2_evr_ts_2'
#  8 b'detector_eh1_jungfrau2_framenum'
#  9 b'detector_eh1_jungfrau2_gain_reg'
#  10 b'detector_eh1_jungfrau2_moduleID'
#  11 b'detector_eh1_jungfrau2_parameters.version'
#  12 b'detector_eh1_jungfrau2_statistics.num_masked'
#  13 b'detector_eh1_jungfrau2_ts'
#  14 b'optics_oh_DCM_DCM.MOVN'
#  15 b'qbpm_eh1_qbpm1_Saturation'
#  16 b'qbpm_eh1_qbpm1_channelMask'
#  17 b'qbpm_eh1_qbpm1_n_channels'
#  18 b'qbpm_eh1_qbpm1_n_samples'
#  19 b'qbpm_eh1_qbpm1_pulse_id'
#  20 b'qbpm_eh1_qbpm1_setting.base_sync'
#  21 b'qbpm_eh1_qbpm1_setting.channelMask'
#  22 b'qbpm_eh1_qbpm1_setting.interleaving_mode'
#  23 b'qbpm_eh1_qbpm1_setting.n_channels'
#  24 b'qbpm_eh1_qbpm1_setting.n_samples'
#  25 b'qbpm_eh1_qbpm1_signal.n_channels'
#  26 b'qbpm_eh1_qbpm1_ts'
#  27 b'qbpm_oh_qbpm2_Saturation'
#  28 b'qbpm_oh_qbpm2_channelMask'
#  29 b'qbpm_oh_qbpm2_n_channels'
#  30 b'qbpm_oh_qbpm2_n_samples'
#  31 b'qbpm_oh_qbpm2_pulse_id'
#  32 b'qbpm_oh_qbpm2_setting.base_sync'
#  33 b'qbpm_oh_qbpm2_setting.channelMask'
#  34 b'qbpm_oh_qbpm2_setting.interleaving_mode'
#  35 b'qbpm_oh_qbpm2_setting.n_channels'
#  36 b'qbpm_oh_qbpm2_setting.n_samples'
#  37 b'qbpm_oh_qbpm2_signal.n_channels'
#  38 b'qbpm_oh_qbpm2_ts'
#  39 b'timestamp_info.pulse_id'
#  40 b'timestamp_info.timestamp_nsec'
#  41 b'timestamp_info.timestamp_sec'
#  42 b'timestamp_info.timestamp_usec'
# block 3
#  0 b'delay_stage_eh1_delay_stage_device'
#  1 b'detector_eh1_jungfrau2_detecor_geometry'
#  2 b'detector_eh1_jungfrau2_device'
#  3 b'detector_eh1_jungfrau2_dtype'
#  4 b'detector_eh1_jungfrau2_event_sync'
#  5 b'detector_eh1_jungfrau2_format'
#  6 b'detector_eh1_jungfrau2_gainmap_version'
#  7 b'detector_eh1_jungfrau2_identifier'
#  8 b'detector_eh1_jungfrau2_mask_version'
#  9 b'detector_eh1_jungfrau2_origin'
#  10 b'detector_eh1_jungfrau2_parameters'
#  11 b'detector_eh1_jungfrau2_parameters.ROI'
#  12 b'detector_eh1_jungfrau2_parameters.aROI'
#  13 b'detector_eh1_jungfrau2_pedestal_version'
#  14 b'detector_eh1_jungfrau2_statistics'
#  15 b'optics_hx_Attns_device'
#  16 b'optics_oh_DCM_device'
#  17 b'qbpm_eh1_qbpm1_base_end'
#  18 b'qbpm_eh1_qbpm1_base_start'
#  19 b'qbpm_eh1_qbpm1_device'
#  20 b'qbpm_eh1_qbpm1_format'
#  21 b'qbpm_eh1_qbpm1_offset'
#  22 b'qbpm_eh1_qbpm1_resolution'
#  23 b'qbpm_eh1_qbpm1_roi_end'
#  24 b'qbpm_eh1_qbpm1_roi_start'
#  25 b'qbpm_eh1_qbpm1_scale'
#  26 b'qbpm_eh1_qbpm1_setting.Inputimp'
#  27 b'qbpm_eh1_qbpm1_setting.Transimp'
#  28 b'qbpm_eh1_qbpm1_setting.Voffset'
#  29 b'qbpm_eh1_qbpm1_setting.Vrange'
#  30 b'qbpm_eh1_qbpm1_setting.base_end'
#  31 b'qbpm_eh1_qbpm1_setting.base_start'
#  32 b'qbpm_eh1_qbpm1_setting.roi_end'
#  33 b'qbpm_eh1_qbpm1_setting.roi_start'
#  34 b'qbpm_oh_qbpm2_base_end'
#  35 b'qbpm_oh_qbpm2_base_start'
#  36 b'qbpm_oh_qbpm2_device'
#  37 b'qbpm_oh_qbpm2_format'
#  38 b'qbpm_oh_qbpm2_offset'
#  39 b'qbpm_oh_qbpm2_resolution'
#  40 b'qbpm_oh_qbpm2_roi_end'
#  41 b'qbpm_oh_qbpm2_roi_start'
#  42 b'qbpm_oh_qbpm2_scale'
#  43 b'qbpm_oh_qbpm2_setting.Inputimp'
#  44 b'qbpm_oh_qbpm2_setting.Transimp'
#  45 b'qbpm_oh_qbpm2_setting.Voffset'
#  46 b'qbpm_oh_qbpm2_setting.Vrange'
#  47 b'qbpm_oh_qbpm2_setting.base_end'
#  48 b'qbpm_oh_qbpm2_setting.base_start'
#  49 b'qbpm_oh_qbpm2_setting.roi_end'
#  50 b'qbpm_oh_qbpm2_setting.roi_start'
#  51 b'timestamp'
#  52 b'timestamp_info'

# %%
print(np.where(to_plot == to_plot.max()))
print(np.where(masked_arr_sum == masked_arr_sum.max()))
# Out:
# (array([377]), array([386]))
# (array([377]), array([386]))

# %%
np.ravel_multi_index([np.argmax(np.nansum(arr, 0))], arr.shape[1:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 np.ravel_multi_index([np.argmax(np.nansum(arr,0))], arr.shape[1:])
#
# ValueError: parameter multi_index must be a sequence of length 2

# %%
test = set(np.reshape(one_zeros_sum, -1))
test
# Out:
# {np.int64(0), np.int64(600)}

# %%
fig1 = plt.figure(figsize=(10, 10))
ax = fig1.add_subplot(111)
ax.plot(listmin, "-o")

# %%
indlist[0][1][0:]
# Out:
# array([   2,    4,    6, ..., 1022, 1024, 1029])

# %%
fig1 = plt.figure(figsize=(10, 10))
ax = fig1.add_subplot(111)
ax.scatter(indlist[0][0], indlist[0][1], 30)
ax.scatter(indlist[400][0], indlist[400][1], 10)
ax.set_aspect(1)
# ax.plot(indlist[100][0], '-o')0
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

# %%
fig1 = plt.figure(figsize=(10, 10))

mask = np.ones((np.shape(arr)[1], np.shape(arr)[2]))
mask[:, :] = arr[0, :, :]
mask[mask < -17500] = np.nan
mask[~np.isnan(mask)] = 1


ax = fig1.add_subplot(211)
img1 = ax.imshow(arr[0, :, :] * mask, interpolation="none")
plt.colorbar(img1)


ax = fig1.add_subplot(212)

img1 = ax.imshow(arr[100, :, :] * mask, interpolation="none")
plt.colorbar(img1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig1 = plt.figure(figsize=(10, 10))
ax = fig1.add_subplot(111)
img1 = ax.imshow(np.nansum(arr, 0) * mask, interpolation="none")
plt.colorbar(img1)

# %%
fig1 = plt.figure(figsize=(10, 10))
ax = fig1.add_subplot(111)
img1 = ax.imshow(arr[100, :, :], interpolation="none")
plt.colorbar(img1)
