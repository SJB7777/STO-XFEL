# %%
import sys
import os

package_path = '..'
if package_path not in sys.path:
    sys.path.append(package_path)

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from src.config.config import load_config
config = load_config()
config.path.load_dir
# Out:
# '/xfel/ffs/dat/ue_240821_FXS/raw_data/h5/type=raw/'

# %%
from src.analyzer.loader import NpzLoader

import matplotlib.pyplot as plt
import numpy as np
from roi_rectangle import RoiRectangle

# %%
run_num: int = 75
print("run_num:", run_num)
processed_dir = config.path.processed_dir
npz_file = os.path.join(processed_dir, f"run={run_num:0>4}_scan=0001.npz")
images = np.load(npz_file)['poff']
print(f"{images.shape = }")
# Out:
# run_num: 75
# images.shape = (81, 514, 1030)

# %%
print(images.min())
# Out:
# -1.0483413

# %%
fig, ax = plt.subplots(1, 1)
ax.imshow(np.log1p(images[40]))
